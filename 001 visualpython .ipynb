# %%
# Visual Python: Data Analysis > Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Visual Python: Data Analysis > File
vp_df = pd.read_csv('../ZERO_ML/Student_Performance.csv')
vp_df
# Out:
#       Hours_Studied  Previous_Scores  Extracurricular_Activities  Sleep_Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
# Visual Python: Data Analysis > Data Info
vp_df.hist()
plt.show()

# %%
# Visual Python: Library > Pandas Plot
vp_df.plot(colormap='viridis')
plt.show()
